# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Data-Science/blob/main/PandasAgain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.iloc[1, 2]
# Out:
# 'some college'

# %%
df_with_names = df.iloc[[1, 3, 6, 10, 11]]
df_with_names.index = ['Dude', 'Linus T', 'Linust tech tips', 'Billy Herrington', 'Quandale Dingle']

# %%
df_with_names
# Out:
#                   gender race/ethnicity parental level of education  \
# Dude              female        group C                some college
# Linus T             male        group A          associate's degree
# Linust tech tips  female        group B                some college
# Billy Herrington    male        group C          associate's degree
# Quandale Dingle     male        group D          associate's degree
#
#                          lunch test preparation course  math score  \
# Dude                  standard               completed          69
# Linus T           free/reduced                    none          47
# Linust tech tips      standard               completed          88
# Billy Herrington      standard                    none          58
# Quandale Dingle       standard                    none          40
#
#                   reading score  writing score
# Dude                         90             88
# Linus T                      57             44
# ...

# %%
df_with_names.loc[['Dude', 'Linus T'], ['lunch', 'math score']]
# Out:
#                 lunch  math score
# Dude         standard          69
# Linus T  free/reduced          47

# %% [markdown]
# Lunch is a key🔑

# %%
df_with_names.iloc[:, 0]
# Out:
# Dude                female
# Linus T               male
# Linust tech tips    female
# Billy Herrington      male
# Quandale Dingle       male
# Name: gender, dtype: object

# %%
df.loc[0:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
len(df[df.lunch == 'free/reduced']) / len(df)
# Out:
# 0.355

# %%
df[df.lunch == 'free/reduced'].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df[df.lunch == 'standard'].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df = df.rename(columns={
    'parental level of education': 'parental level of education'.replace(' ', '_'),
    'test preparation course': 'test preparation course'.replace(' ', '_'),
    'math score': 'math score'.replace(' ', '_'),
    'reading score': 'reading score'.replace(' ', '_'),
    'writing score': 'writing score'.replace(' ', '_')

})

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# same to df[df['math_score'] > 70]
df.query('math_score > 70')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.query("gender == 'female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# shows only columns with score in name of column
df.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
# we can also use it with axis arg
# axis=1 - vertical(columns), axis=0 - horizontal(rows)
df_with_names.filter(like='L', axis=0)
# Out:
#                   gender race/ethnicity parental level of education  \
# Linus T             male        group A          associate's degree
# Linust tech tips  female        group B                some college
#
#                          lunch test preparation course  math score  \
# Linus T           free/reduced                    none          47
# Linust tech tips      standard               completed          88
#
#                   reading score  writing score
# Linus T                      57             44
# Linust tech tips             95             92

# %%
df_with_names.filter(like='g', axis=1)
# Out:
#                   gender  reading score  writing score
# Dude              female             90             88
# Linus T             male             57             44
# Linust tech tips  female             95             92
# Billy Herrington    male             54             52
# Quandale Dingle     male             52             43
