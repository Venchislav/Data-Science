# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Data-Science/blob/main/Passenger_Satisfaction_SGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/content/sample_data/train.csv', index_col='id')
test = pd.read_csv('/content/sample_data/test.csv', index_col='id')

# %%
train.head()
# Out:
#         Unnamed: 0  Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 70172            0    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 5047             1    Male  disloyal Customer   25  Business travel  Business
# 110028           2  Female     Loyal Customer   26  Business travel  Business
# 24026            3  Female     Loyal Customer   25  Business travel  Business
# 119299           4    Male     Loyal Customer   61  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 70172               460                      3
# 5047                235                      3
# 110028             1142                      2
# 24026               562                      2
# 119299              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# id                                                                 ...
# ...

# %%
test.head()
# Out:
#        Unnamed: 0  Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 19556           0  Female     Loyal Customer   52  Business travel       Eco
# 90035           1  Female     Loyal Customer   36  Business travel  Business
# 12360           2    Male  disloyal Customer   20  Business travel       Eco
# 77959           3    Male     Loyal Customer   44  Business travel  Business
# 36875           4  Female     Loyal Customer   49  Business travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# id
# 19556              160                      5
# 90035             2863                      1
# 12360              192                      2
# 77959             3377                      0
# 36875             1182                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# id                                                                ...
# ...

# %%
test = test.drop('Unnamed: 0', axis=1)
train = train.drop('Unnamed: 0', axis=1)

# %%
train.head()
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 70172     Male     Loyal Customer   13  Personal Travel  Eco Plus
# 5047      Male  disloyal Customer   25  Business travel  Business
# 110028  Female     Loyal Customer   26  Business travel  Business
# 24026   Female     Loyal Customer   25  Business travel  Business
# 119299    Male     Loyal Customer   61  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 70172               460                      3
# 5047                235                      3
# 110028             1142                      2
# 24026               562                      2
# 119299              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# id
# 70172                                   4                       3
# 5047                                    2                       3
# ...

# %%
train['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
train['Class'].value_counts()
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
train.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['satisfaction'])
train['satisfaction'] = le.transform(train['satisfaction'])

le.fit(test['satisfaction'])
test['satisfaction'] = le.transform(test['satisfaction'])

# %%
train.head()
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 70172     Male     Loyal Customer   13  Personal Travel  Eco Plus
# 5047      Male  disloyal Customer   25  Business travel  Business
# 110028  Female     Loyal Customer   26  Business travel  Business
# 24026   Female     Loyal Customer   25  Business travel  Business
# 119299    Male     Loyal Customer   61  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 70172               460                      3
# 5047                235                      3
# 110028             1142                      2
# 24026               562                      2
# 119299              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# id
# 70172                                   4                       3
# 5047                                    2                       3
# ...

# %%
train['Arrival Delay in Minutes'].corr(train['satisfaction'])
# Out:
# -0.05758182372581

# %%
train = train.dropna()
# mean_ = train['Arrival Delay in Minutes'].mean()
# train['Arrival Delay in Minutes'].fillna(mean_, inplace=True)

# %%
test.isnull().sum()
# Out:
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             83
# satisfaction                          0
# dtype: int64

# %%
test = test.dropna()
# mean_test = test['Arrival Delay in Minutes'].mean()
# test['Arrival Delay in Minutes'].fillna(mean_test, inplace=True)

# %% [markdown]
# # **PLOTS**✈

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.title('Satisfaction countplot(where 1-Satisfied, 0-Unsatisfied)')
sns.countplot(data=train, x='satisfaction');

# %%
plt.title('Male and Female countplot(where 1-Male, 0-Female)')
sns.countplot(data=train, x='Gender');

# %%
plt.title('Age Distribution')
sns.distplot(train['Age']);

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(train.corr(), annot=True, fmt='.2f');

# %% [markdown]
# # **DATA PREPROCESSING**

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103594 entries, 70172 to 62567
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103594 non-null  object
#  1   Customer Type                      103594 non-null  object
#  2   Age                                103594 non-null  int64
#  3   Type of Travel                     103594 non-null  object
#  4   Class                              103594 non-null  object
#  5   Flight Distance                    103594 non-null  int64
#  6   Inflight wifi service              103594 non-null  int64
#  7   Departure/Arrival time convenient  103594 non-null  int64
#  8   Ease of Online booking             103594 non-null  int64
#  9   Gate location                      103594 non-null  int64
#  10  Food and drink                     103594 non-null  int64
# ...

# %%
train.head(1)
# Out:
#       Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# id
# 70172   Male  Loyal Customer   13  Personal Travel  Eco Plus              460
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# id
# 70172                      3                                  4
#
#        Ease of Online booking  Gate location  ...  Inflight entertainment  \
# id                                            ...
# 70172                       3              1  ...                       5
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# id
# 70172                 4                 3                 4                4
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# id
# 70172                 5            5                          25
#
#        Arrival Delay in Minutes  satisfaction
# id
# 70172                      18.0             0
#
# [1 rows x 23 columns]

# %%
train['Type of Travel'].value_counts()
# Out:
# Business travel    71465
# Personal Travel    32129
# Name: Type of Travel, dtype: int64

# %%
train['Customer Type'].value_counts()
# Out:
# Loyal Customer       84662
# disloyal Customer    18932
# Name: Customer Type, dtype: int64

# %%
le.fit(train['Gender'])
train['Gender'] = le.transform(train['Gender'])

# %%
le.fit(test['Gender'])
test['Gender'] = le.transform(test['Gender'])

# %%
train.head()
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 70172        1     Loyal Customer   13  Personal Travel  Eco Plus
# 5047         1  disloyal Customer   25  Business travel  Business
# 110028       0     Loyal Customer   26  Business travel  Business
# 24026        0     Loyal Customer   25  Business travel  Business
# 119299       1     Loyal Customer   61  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 70172               460                      3
# 5047                235                      3
# 110028             1142                      2
# 24026               562                      2
# 119299              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# id
# 70172                                   4                       3
# 5047                                    2                       3
# ...

# %%
train = pd.get_dummies(train)

# %%
train.head()
# Out:
#         Gender  Age  Flight Distance  Inflight wifi service  \
# id
# 70172        1   13              460                      3
# 5047         1   25              235                      3
# 110028       0   26             1142                      2
# 24026        0   25              562                      2
# 119299       1   61              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# id
# 70172                                   4                       3
# 5047                                    2                       3
# 110028                                  2                       2
# 24026                                   5                       5
# 119299                                  3                       3
#
#         Gate location  Food and drink  Online boarding  Seat comfort  ...  \
# id                                                                    ...
# ...

# %%
test = pd.get_dummies(test)

# %%
test.head()
# Out:
#        Gender  Age  Flight Distance  Inflight wifi service  \
# id
# 19556       0   52              160                      5
# 90035       0   36             2863                      1
# 12360       1   20              192                      2
# 77959       1   44             3377                      0
# 36875       0   49             1182                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# id
# 19556                                  4                       3
# 90035                                  1                       3
# 12360                                  0                       2
# 77959                                  0                       0
# 36875                                  3                       4
#
#        Gate location  Food and drink  Online boarding  Seat comfort  ...  \
# id                                                                   ...
# ...

# %%
X_train = train.drop('satisfaction', axis=1)
y_train = train['satisfaction']

# %%
X_test = test.drop('satisfaction', axis=1)
y_test = test['satisfaction']

# %%
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print('=' * 60)
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (103594, 26)
# y_train shape: (103594,)
# ...
# X_test shape: (25893, 26)
# y_test shape: (25893,)

# %% [markdown]
# # **MODEL**

# %% [markdown]
# **I will follow this official cheat sheet from sklearn:** <br>
# ![CheatSheet.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import SGDClassifier

# %%
clf = SGDClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# SGDClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8434712084347121

# %% [markdown]
# P.S - Mayb it's not the best code.
# But it's beginner friendly as I'm beginner too👶

# %% [markdown]
# # **P.S CODE ALSO AVAILABLE ON <a href='https://www.kaggle.com/code/venchislav/passenger-satisfaction-sgd-beginner-friendly'>KAGGLE</a>**
