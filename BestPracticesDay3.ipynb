# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Data-Science/blob/main/BestPracticesDay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data survey is very important in machine learning
# "You have to know your enemy"
# I'm not sure it's suitable here...
# but...

# %%
df = pd.read_csv('/content/sample_data/train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
# df.describe shows us some stats of provided data
# Here I also used iloc to show stats for first and last column

# %%
df.describe().iloc[:, [0, -1]]
# Out:
#        PassengerId        Fare
# count   891.000000  891.000000
# mean    446.000000   32.204208
# std     257.353842   49.693429
# min       1.000000    0.000000
# 25%     223.500000    7.910400
# 50%     446.000000   14.454200
# 75%     668.500000   31.000000
# max     891.000000  512.329200

# %%
# but these were quiet easy
# Let's start ploting (oh no)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.histplot(data=df, x='Fare')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(df, x="Fare", hue="Survived", element="poly")
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# hists are cool. And they make you look cool and smart
# nerd...🤓

# %%
# let's play with scatters now

# %%
df.plot.scatter(x='Age', y='Fare', alpha=0.3)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df['Age'].corr(df['Fare'])
# Out:
# 0.0960666917690389

# %%
# Now let's build power ranger!

# %%
from yellowbrick.features import JointPlotVisualizer

# %%
df = df.dropna()

# %%
jpv = JointPlotVisualizer(feature='Age', target='Fare')

# %%
# now let's plot here:

jpv.fit(df['Age'], df['Fare'])
# Out:
# JointPlot(ax=<Axes: xlabel='x', ylabel='y'>)

# %%
jpv.poof()
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# Now I'm tired
# But I have scool holidays (thx God!)
# so it'll be more code since friday 27th
# But now:

# %% [markdown]
# <img src='https://img.izismile.com/img/img6/20130916/640/cool_backstage_photos_from_the_set_of_breaking_bad_640_06.jpg' width=35%><br>
# ___
#
# **Have a good day!**
