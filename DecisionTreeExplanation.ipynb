# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Data-Science/blob/main/DecisionTreeExplanation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hey vsauce! Michael here! DECISION TREE IS UNDERSTANDABLE... Or is it? <br>
# "Vsauce theme"

# %% [markdown]
# Here is an example of decision tree: <br>
# ![DECISIONTREE-EXAMPLE.png](data:image/png;base64,...)

# %% [markdown]
# Yeah... It looks like typical if-else statement...
#
# ![MEME.png](data:image/png;base64,...)

# %% [markdown]
# Kinda explanation IDK...

# %% [markdown]
# ![Example.png](data:image/png;base64,...)

# %%
# LADIES AN GENTLEMAN... Entropy!!!

# %% [markdown]
# # **Example 1** <br>
# ![Enthropy.png](data:image/png;base64,...)

# %% [markdown]
# Here the entropy equals `-chance of getting "No" * log(chance of getting No) - chance of getting "Yes" * log(chance of getting Yes)`
#
#
# As a DataScientists we have to try our best to lower the entropy (as I understood) cause Entropy is a measure of ***uncertainty***

# %% [markdown]
# # **Example 2** <br>
# ![Entropy2.png](data:image/png;base64,...)

# %% [markdown]
# For the question "Survived?":
# We have 100% chance of death ("No") and 0% of survive ("Yes")
# We build our Entropy formula in this way:

# %% [markdown]
# The same thing is about 100% of surviving <br>
# ![Entropy.png](data:image/png;base64,...)

# %% [markdown]
# NO PAIN NO INFORMATION GAIN!
# I mean...

# %% [markdown]
# ![Gain.png](data:image/png;base64,...)

# %% [markdown]
# This is a formula for IG where:
# E(Y) = n2(number of samples in our decision)/N(total number of samples)*E(entropy)
# and the same thing about E(X)

# %% [markdown]
# # **For this data**
# ![Data.png](data:image/png;base64,...)

# %% [markdown]
# # **We Get Formula:**
# ![formula.png](data:image/png;base64,...)

# %% [markdown]
# # **P.S Here's a mistake:**
# ![Снимок1.PNG](data:image/png;base64,...)

# %% [markdown]
# # **❗❗❗❗❗❗❗🔥🔥🔥VEEEEEEEEEEEEEERY COOL VIDEO ABOUT DECISION TREE🔥🔥🔥❗❗❗❗❗❗❗**
#
# https://www.youtube.com/watch?v=dQw4w9WgXcQ
