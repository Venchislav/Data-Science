# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Data-Science/blob/main/I'm_psycho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Origin:** <br>
# **We were given a computer science test using Excel tables.<br> And since I’m a novice data scientist (and a bit of a dork)<br> I decided to work with this data in Pandas**

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/sample_data/14-2.xlsx')
df.head()
# Out:
#   округ   фамилия          предмет  балл
# 0     Ц  Уч-00001  английский язык    56
# 1     З  Уч-00002      информатика    90
# 2     В  Уч-00003     русский язык    15
# 3     С  Уч-00004  английский язык    23
# 4     Ц  Уч-00005   обществознание    92

# %%
df[df['предмет']=='английский язык']['балл'].mean()
# Out:
# 56.611111111111114

# %%
a = df[(df['предмет']=='физика') | (df['предмет']=='химия')]
a[a['балл'] > 70].shape
# Out:
# (48, 4)

# %%
# I did my homework with python pandas insetad of excel

# %% [markdown]
# <img src='https://media.tenor.com/oLAXXJxlPvkAAAAd/sigma.gif' width=35%>

# %%
# Now let's have some fun

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#   округ   фамилия          предмет  балл
# 0     Ц  Уч-00001  английский язык    56
# 1     З  Уч-00002      информатика    90
# 2     В  Уч-00003     русский язык    15
# 3     С  Уч-00004  английский язык    23
# 4     Ц  Уч-00005   обществознание    92

# %%
df = df.drop('фамилия', axis=1)

# %%
df = pd.get_dummies(df)

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(), annot=True, fmt='.2f');

# %%
df.head()
# Out:
#    балл  округ_В  округ_З  округ_С  округ_Ц  округ_Ю  предмет_английский язык  \
# 0    56        0        0        0        1        0                        1
# 1    90        0        1        0        0        0                        0
# 2    15        1        0        0        0        0                        0
# 3    23        0        0        1        0        0                        1
# 4    92        0        0        0        1        0                        0
#
#    предмет_биология  предмет_география  предмет_информатика  \
# 0                 0                  0                    0
# 1                 0                  0                    1
# 2                 0                  0                    0
# 3                 0                  0                    0
# 4                 0                  0                    0
#
#    предмет_литература  предмет_математика  предмет_обществознание  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X, y = df.drop('балл', axis=1), df['балл']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
from sklearn.svm import SVR

# %%
regr = SVR()
regr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = regr.predict(X_test)

# %%
y_pred[:20]
# Out:
# array([49.16254958, 44.61112081, 52.77913597, 52.13134388, 50.05096397,
#        52.89942628, 49.52284733, 52.77913597, 44.9315835 , 47.39111339,
#        53.10031518, 48.91776743, 52.77913597, 51.91254833, 49.52284733,
#        49.3295986 , 49.50159759, 46.22534331, 48.14447623, 48.71755439])

# %%
y_test[:20]
# Out:
# 115    35
# 492    60
# 549    72
# 311    45
# 682    78
# 334    25
# 872    22
# 74     38
# 201    38
# 700    79
# 906    50
# 241    93
# 713    34
# 653    90
# 545    23
# 968    80
# 989    48
# 321    20
# 747    26
# 265    67
# Name: балл, dtype: int64

# %%
regr.score(X_train, y_train) * 100
# Out:
# 2.9556348822666445

# %%
df.shape
# Out:
# (1000, 16)

# %%
# 3% accuracy... It's terrible... I mean we have only 1000 features, but maybe th

# %%
# alright, I build heatmap and... It sucks...
# Creator of this excel table (in my case dataset) is an assh😎le who used random values (I guess)

# %%
# Fine, anyway I did my homework with pandas and python

# %% [markdown]
# <img src='data:image/jpeg;base64,...'>
